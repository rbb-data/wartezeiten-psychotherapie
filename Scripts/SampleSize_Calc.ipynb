# %%
import pandas as pd
import numpy as np

# %%
praxenzahl=pd.read_excel("../RawData/AnzahlPraxen.xlsx",sheet_name="Grad_der_Verstädterung",skiprows=6,dtype=str)
praxenzahl
# Out:
# /usr/local/lib/python3.9/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#                                            Unnamed: 0 Unnamed: 1  \
# 0                                                  01        NaN
# 1                                                  01         01
# 2                                                  01         02
# 3                                                  01         03
# 4                                                  02        NaN
# ..                                                ...        ...
# 68       nur bedingt mit den Vorjahreswerten vegle...        NaN
# 69                                                NaN        NaN
# 70  © Daten (im Auftrag der Herausgebergemeinschaf...        NaN
# 71           Statistisches Bundesamt (Destatis), 2021        NaN
# 72       Vervielfältigung und Verbreitung, auch au...        NaN
#
# ...

# %%
praxenzahl_columnlist=["Land","Grad der Verstädterung","Bezeichnung","Fläche in km2",
                       'Bevölkerung insgesamt', 'Bevölkerung männlich', 'Bevölkerung weiblich',"Bevölkerung pro km2",
                       "Fläche_Prozent","Bevölkerung_Prozent","Praxen_gesamt_Sample","Praxen_BB_Sample"]

# %%
praxenzahl_columnlist=["Land","Grad der Verstädterung","Bezeichnung","Fläche in km2",
                       'Bevölkerung insgesamt', 'Bevölkerung männlich', 'Bevölkerung weiblich',"Bevölkerung pro km2",
                       "Fläche_Prozent","Bevölkerung_Prozent","Praxen_gesamt_Sample","Praxen_BB_Sample"]
praxenzahl.columns=praxenzahl_columnlist
praxenzahl_reduced=praxenzahl.dropna(subset=["Grad der Verstädterung","Land"])
praxenzahl_reduced["Praxen_gesamt_Sample"]=pd.to_numeric(praxenzahl_reduced["Praxen_gesamt_Sample"])
praxenzahl_reduced["Praxen_BB_Sample"]=pd.to_numeric(praxenzahl_reduced["Praxen_BB_Sample"])
praxenzahl_reduced["Praxen_gesamt_Sample"]=praxenzahl_reduced["Praxen_gesamt_Sample"].apply(np.ceil)
praxenzahl_reduced["Praxen_BB_Sample"]=praxenzahl_reduced["Praxen_BB_Sample"].apply(np.ceil)
praxenzahl_reduced["Praxen_BB_Sample"]=praxenzahl_reduced["Praxen_BB_Sample"].fillna(0)
praxenzahl_reduced["Sample"]=praxenzahl_reduced["Praxen_BB_Sample"]+praxenzahl_reduced["Praxen_gesamt_Sample"]
praxenzahl_reduced
# Out:
# /usr/local/lib/python3.9/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
#    Land Grad der Verstädterung                    Bezeichnung Fläche in km2  \
# 1    01                     01                dicht besiedelt        683.47
# 2    01                     02     mittlere Besiedlungsdichte       2458.45
# 3    01                     03               gering besiedelt      12662.39
# 5    02                     01                dicht besiedelt        755.09
# 7    03                     01                dicht besiedelt       1708.49
# 8    03                     02     mittlere Besiedlungsdichte      16280.35
# ...

# %%
columnnlist=['Satzart', 'Kennzeichen', 'Land', 'RB', 'Kreis', 'VB', 'Gem',
       'Gemeindename', 'Fläche', 'Bevölkerung insgesamt', 'Bevölkerung männlich', 'Bevölkerung weiblich',
       'je km2', 'PLZ', 'Längengrad', 'Breitengrad', 'Reisegebiet-Schlüssel',
       'Reisegebiet-Bezeichnung', 'Verstädterung-Schlüssel', 'Verstädterung_Bezeichnung']

# %%
data=pd.read_excel("../RawData/AuszugGV4QAktuell.xlsx",sheet_name="Onlineprodukt_Gemeinden",skiprows=4,dtype=str)
data
# Out:
#                                               Unnamed: 0 Unnamed: 1  \
# 0                                                    NaN        NaN
# 1                                                     10        NaN
# 2                                                     40         41
# 3                                                     50         50
# 4                                                     60         61
# ...                                                  ...        ...
# 16068  3) Die Gemeinde kann mehrere Postleitzahlen (P...        NaN
# 16069                                                NaN        NaN
# 16070  © Daten (im Auftrag der Herausgebergemeinschaf...        NaN
# 16071           Statistisches Bundesamt (Destatis), 2022        NaN
# 16072       Vervielfältigung und Verbreitung, auch au...        NaN
#
#       Gebietsstand am 31.12.2021 (4. Quartal) Unnamed: 3 Unnamed: 4  \
# 0                                         NaN        NaN        NaN
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Gebietsstand am 31.12.2021 (4. Quartal)',
#        'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#        '31.12.2020 (Jahr)', 'am 31.12.2020 (Jahr)', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Zuordnungsstand am 31.12.2020', 'Unnamed: 15', 'Schlüssel',
#        'Bezeichnung', 'Schlüssel.1', 'Bezeichnung.1'],
#       dtype='object')

# %%
columnnlist=['Satzart', 'Kennzeichen', 'Land', 'RB', 'Kreis', 'VB', 'Gem',
       'Gemeindename', 'Fläche', 'Bevölkerung insgesamt', 'Bevölkerung männlich', 'Bevölkerung weiblich',
       'je km2', 'PLZ', 'Längengrad', 'Breitengrad', 'Reisegebiet-Schlüssel',
       'Reisegebiet-Bezeichnung', 'Verstädterung-Schlüssel', 'Verstädterung_Bezeichnung']

# %%
data.columns=columnnlist
data.dropna(subset=['Verstädterung_Bezeichnung'])
# Out:
#       Satzart Kennzeichen Land RB Kreis    VB  Gem            Gemeindename  \
# 4          60          61   01  0    01  0000  000        Flensburg, Stadt
# 7          60          61   01  0    02  0000  000  Kiel, Landeshauptstadt
# 10         60          61   01  0    03  0000  000      Lübeck, Hansestadt
# 13         60          61   01  0    04  0000  000       Neumünster, Stadt
# 16         60          63   01  0    51  0011  011      Brunsbüttel, Stadt
# ...       ...         ...  ... ..   ...   ...  ...                     ...
# 16055      60          64   16  0    77  5051  011             Göpfersdorf
# 16056      60          64   16  0    77  5051  023  Langenleuba-Niederhain
# 16057      60          64   16  0    77  5051  036                  Nobitz
# 16059      60          64   16  0    77  5052  003              Dobitschen
# 16060      60          63   16  0    77  5052  043         Schmölln, Stadt
#
# ...

# %%
data["Bevölkerung insgesamt"]=pd.to_numeric(data["Bevölkerung insgesamt"])

# %%
praxenzahl_reduced
# Out:
#    Land Grad der Verstädterung                    Bezeichnung Fläche in km2  \
# 1    01                     01                dicht besiedelt        683.47
# 2    01                     02     mittlere Besiedlungsdichte       2458.45
# 3    01                     03               gering besiedelt      12662.39
# 5    02                     01                dicht besiedelt        755.09
# 7    03                     01                dicht besiedelt       1708.49
# 8    03                     02     mittlere Besiedlungsdichte      16280.35
# 9    03                     03               gering besiedelt      29720.99
# 11   04                     01                dicht besiedelt        419.62
# 13   05                     01                dicht besiedelt       5933.82
# 14   05                     02     mittlere Besiedlungsdichte      19244.97
# 15   05                     03               gering besiedelt       8933.66
# ...

# %%
data
# Out:
#                                                  Satzart Kennzeichen Land  \
# 0                                                    NaN         NaN  NaN
# 1                                                     10         NaN   01
# 2                                                     40          41   01
# 3                                                     50          50   01
# 4                                                     60          61   01
# ...                                                  ...         ...  ...
# 16068  3) Die Gemeinde kann mehrere Postleitzahlen (P...         NaN  NaN
# 16069                                                NaN         NaN  NaN
# 16070  © Daten (im Auftrag der Herausgebergemeinschaf...         NaN  NaN
# 16071           Statistisches Bundesamt (Destatis), 2022         NaN  NaN
# 16072       Vervielfältigung und Verbreitung, auch au...         NaN  NaN
#
#         RB Kreis    VB  Gem        Gemeindename Fläche  Bevölkerung insgesamt  \
# ...

# %%
samplelist=[]
for index,row in praxenzahl_reduced.iterrows():
    print(row["Land"],row["Bezeichnung"],row["Sample"])
    landcode=row["Land"]
    verstaedterung=row["Bezeichnung"]
    samplezahl=row["Sample"]
    filtered_data=data[data.eval("Land=='"+landcode+"'& Verstädterung_Bezeichnung=='"+verstaedterung.strip()+"'")]
    weights_list=(filtered_data["Bevölkerung insgesamt"]/filtered_data["Bevölkerung insgesamt"].sum()).tolist()

    for i in range(int(samplezahl*20)):
        weighted_random_sample = filtered_data.sample(weights=weights_list)
        samplerow=[weighted_random_sample["Gemeindename"].values[0],weighted_random_sample["PLZ"].values[0] ,landcode,verstaedterung,samplezahl]
        samplelist.append(samplerow)
Sample_of_Adresses=pd.DataFrame(samplelist,columns=["Gemeinde","PLZ","BL","Verstädterung","Sample"])
Sample_of_Adresses
# Out:
# 01    dicht besiedelt 2.0
# 01    mittlere Besiedlungsdichte 2.0
# 01    gering besiedelt 2.0
# 02    dicht besiedelt 3.0
# 03    dicht besiedelt 3.0
# 03    mittlere Besiedlungsdichte 5.0
# 03    gering besiedelt 3.0
# 04    dicht besiedelt 1.0
# 05    dicht besiedelt 12.0
# 05    mittlere Besiedlungsdichte 9.0
# 05    gering besiedelt 2.0
# 06    dicht besiedelt 3.0
# 06    mittlere Besiedlungsdichte 4.0
# 06    gering besiedelt 2.0
# 07    dicht besiedelt 2.0
# 07    mittlere Besiedlungsdichte 3.0
# 07    gering besiedelt 2.0
# 08    dicht besiedelt 4.0
# 08    mittlere Besiedlungsdichte 8.0
# 08    gering besiedelt 3.0
# 09    dicht besiedelt 5.0
# 09    mittlere Besiedlungsdichte 7.0
# 09    gering besiedelt 6.0
# 10    dicht besiedelt 1.0
# 10    mittlere Besiedlungsdichte 1.0
# 10    gering besiedelt 1.0
# 11    dicht besiedelt 36.0
# 12    dicht besiedelt 6.0
# 12    mittlere Besiedlungsdichte 13.0
# 12    gering besiedelt 8.0
# 13    dicht besiedelt 1.0
# ...

# %%
Sample_of_Adresses
# Out:
#                     Gemeinde    PLZ  BL        Verstädterung  Sample
# 0         Norderstedt, Stadt  22846  01      dicht besiedelt     2.0
# 1     Kiel, Landeshauptstadt  24103  01      dicht besiedelt     2.0
# 2     Kiel, Landeshauptstadt  24103  01      dicht besiedelt     2.0
# 3        Wentorf bei Hamburg  21465  01      dicht besiedelt     2.0
# 4         Lübeck, Hansestadt  23539  01      dicht besiedelt     2.0
# ...                      ...    ...  ..                  ...     ...
# 3535              Gerstungen  99834  16     gering besiedelt     1.0
# 3536      Hörselberg-Hainich  99820  16     gering besiedelt     1.0
# 3537               Nauendorf  99448  16     gering besiedelt     1.0
# 3538                Oberbösa  99718  16     gering besiedelt     1.0
# 3539              Wiesenthal  36466  16     gering besiedelt     1.0
#
# [3540 rows x 5 columns]

# %%
Sample_of_Adresses.iloc[110]
# Out:
# Gemeinde              Klein Bennebek
# PLZ                            24848
# BL                                01
# Verstädterung       gering besiedelt
# Sample                           2.0
# Name: 110, dtype: object

# %%
filter1=praxenzahl.where(praxenzahl["Grad der Verstädterung"].isna())
BL=filter1[filter1["Bezeichnung"].notnull()]
BL_codes=BL[["Land","Bezeichnung"]]
BL_codes
SampleFrame_With_BL=pd.merge(BL_codes,Sample_of_Adresses,left_on="Land",right_on="BL")
SampleFrame_With_BL
# Out:
#      Land         Bezeichnung                Gemeinde    PLZ  BL  \
# 0      01  Schleswig-Holstein      Norderstedt, Stadt  22846  01
# 1      01  Schleswig-Holstein  Kiel, Landeshauptstadt  24103  01
# 2      01  Schleswig-Holstein  Kiel, Landeshauptstadt  24103  01
# 3      01  Schleswig-Holstein     Wentorf bei Hamburg  21465  01
# 4      01  Schleswig-Holstein      Lübeck, Hansestadt  23539  01
# ...   ...                 ...                     ...    ...  ..
# 3535   16           Thüringen              Gerstungen  99834  16
# 3536   16           Thüringen      Hörselberg-Hainich  99820  16
# 3537   16           Thüringen               Nauendorf  99448  16
# 3538   16           Thüringen                Oberbösa  99718  16
# 3539   16           Thüringen              Wiesenthal  36466  16
#
#             Verstädterung  Sample
# 0         dicht besiedelt     2.0
# 1         dicht besiedelt     2.0
# 2         dicht besiedelt     2.0
# 3         dicht besiedelt     2.0
# ...

# %%
SampleFrame_With_BL.to_csv("samplesgemeinde.csv",index=False)

# %% [markdown]
# weightage = [0.1, 0.1, 0.2, 0.2, 0.4]
#
# students = {'Name':['Tony', 'Jake', 'Sullivan', 'Peter', 'Emma'],
# 		'Age': [14, 14, 15, 17, 16],
# 		'Favorite subject': ['Maths', 'General Science', 'Social Studies', 'English Literature', 'Computer Science'],
# 		'Hobby': ['Writing', 'Gardening', 'Coin collection', 'Reading', 'Programming']}
#
# df = pd.DataFrame(students)
# weighted_sample = df.sample(weights=weightage)
